# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguin = sns.load_dataset('penguins')

# %%
print(penguin.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.distplot(penguin['bill_length_mm'])
# Out:
# C:\Users\wayne\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.distplot(penguin['body_mass_g'],hist='False')
# Out:
# C:\Users\wayne\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.jointplot(x='bill_length_mm',y='bill_depth_mm',data=penguin)
plt.show()

# %%
sns.jointplot(x='bill_length_mm',y='flipper_length_mm',data=penguin)
plt.show()

# %%
sns.jointplot(x='bill_depth_mm',y='flipper_length_mm',data=penguin)
plt.show()

# %%
sns.scatterplot(x='bill_depth_mm',y='flipper_length_mm',data=penguin)
plt.show()

# %%
sns.set_style('ticks')
sns.pairplot(penguin)
plt.show()

# %%
sns.stripplot(x='species',y='bill_length_mm',data=penguin)
plt.show()

# %%
sns.swarmplot(x='species',y='bill_length_mm',data=penguin)
plt.show()

# %%
sns.boxplot(x=penguin['flipper_length_mm'])
plt.show()

# %%
sns.boxplot(x='species',y='bill_depth_mm',data=penguin)
plt.show()

# %%
sns.violinplot(x=penguin["species"],y=penguin['bill_length_mm'])
plt.show()

# %%
sns.barplot(x='species',y='bill_length_mm',data=penguin)
plt.show()

# %%
sns.pointplot(x='species',y='bill_length_mm',data=penguin)
plt.show()

# %%
sns.regplot(x='bill_depth_mm',y='bill_length_mm',data=penguin)
plt.show()

# %%
sns.residplot(x='bill_depth_mm',y='bill_length_mm',data=penguin)
plt.show()

# %%
uniform_data = np.random.rand(10,12)
sns.heatmap(uniform_data)
plt.show()

# %%
df1 = penguin[['bill_length_mm','bill_depth_mm']]

# %%
sns.clustermap(df1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-636faad8d5e2> in <module>
# ----> 1 sns.clustermap(df1)
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1400                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1401
# -> 1402     return plotter.plot(metric=metric, method=method,
# ...

# %%
sns.FacetGrid(penguin,col='species',row='island')
plt.show()

# %%
g = sns.FacetGrid(penguin,col='species',row='island')
g = g.map(plt.hist,"body_mass_g")
plt.show()

# %%
g = sns.PairGrid(penguin)
g = g.map(plt.scatter)
plt.show()

# %%
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
